# %%
# Dependencies and Setup

import os
import json
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# Data Source
# https://www.kaggle.com/nasa/meteorite-landings

# %%
# File to Load

meteorcsv_path = ("C:/Users/ekatu/code/Project_2/Project-2-VisualizeMe2/Data/meteorite-landings.csv")
# C:\Users\ekatu\code\Project_2\Project-2-VisualizeMe2\Data



# Read the meteorite data
csv_meteors = pd.read_csv(meteorcsv_path)
csv_meteors
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# 0      1880.0  50.77500    6.08333     (50.775000, 6.083330)
# 1      1951.0  56.18333   10.23333    (56.183330, 10.233330)
# 2      1952.0  54.21667 -113.00000  (54.216670, -113.000000)
# 3      1976.0  16.88333  -99.90000   (16.883330, -99.900000)
# 4      1902.0 -33.16667  -64.95000  (-33.166670, -64.950000)
# ...       ...       ...        ...                       ...
# 45711  1990.0  29.03700   17.01850    (29.037000, 17.018500)
# 45712  1999.0  13.78333    8.96667     (13.783330, 8.966670)
# 45713  1939.0  49.25000   17.66667    (49.250000, 17.666670)
# 45714  2003.0  49.78917   41.50460    (49.789170, 41.504600)
# 45715  1976.0  33.98333 -115.68333  (33.983330, -115.683330)
#
# [45716 rows x 10 columns]

# %%
# Drop unnecessary columns
del csv_meteors["nametype"]
csv_meteors.head()
# Out:
#        name   id     recclass      mass  fall    year    reclat    reclong  \
# 0    Aachen    1           L5      21.0  Fell  1880.0  50.77500    6.08333
# 1    Aarhus    2           H6     720.0  Fell  1951.0  56.18333   10.23333
# 2      Abee    6          EH4  107000.0  Fell  1952.0  54.21667 -113.00000
# 3  Acapulco   10  Acapulcoite    1914.0  Fell  1976.0  16.88333  -99.90000
# 4   Achiras  370           L6     780.0  Fell  1902.0 -33.16667  -64.95000
#
#                 GeoLocation
# 0     (50.775000, 6.083330)
# 1    (56.183330, 10.233330)
# 2  (54.216670, -113.000000)
# 3   (16.883330, -99.900000)
# 4  (-33.166670, -64.950000)

# %%
del csv_meteors["fall"]
csv_meteors.head()
# Out:
#        name   id     recclass      mass    year    reclat    reclong  \
# 0    Aachen    1           L5      21.0  1880.0  50.77500    6.08333
# 1    Aarhus    2           H6     720.0  1951.0  56.18333   10.23333
# 2      Abee    6          EH4  107000.0  1952.0  54.21667 -113.00000
# 3  Acapulco   10  Acapulcoite    1914.0  1976.0  16.88333  -99.90000
# 4   Achiras  370           L6     780.0  1902.0 -33.16667  -64.95000
#
#                 GeoLocation
# 0     (50.775000, 6.083330)
# 1    (56.183330, 10.233330)
# 2  (54.216670, -113.000000)
# 3   (16.883330, -99.900000)
# 4  (-33.166670, -64.950000)

# %%
del csv_meteors["GeoLocation"]
csv_meteors.head()
# Out:
#        name   id     recclass      mass    year    reclat    reclong
# 0    Aachen    1           L5      21.0  1880.0  50.77500    6.08333
# 1    Aarhus    2           H6     720.0  1951.0  56.18333   10.23333
# 2      Abee    6          EH4  107000.0  1952.0  54.21667 -113.00000
# 3  Acapulco   10  Acapulcoite    1914.0  1976.0  16.88333  -99.90000
# 4   Achiras  370           L6     780.0  1902.0 -33.16667  -64.95000

# %%
# Check for incomplete rows
csv_meteors.count()
# Out:
# name        45716
# id          45716
# recclass    45716
# mass        45585
# year        45428
# reclat      38401
# reclong     38401
# dtype: int64

# %%
# Rename columns
csv_meteors_new = csv_meteors.rename(columns={'recclass':'classification', 'reclat':'latitude', 'reclong':'longitude'})
csv_meteors_new.head()
# Out:
#        name   id classification      mass    year  latitude  longitude
# 0    Aachen    1             L5      21.0  1880.0  50.77500    6.08333
# 1    Aarhus    2             H6     720.0  1951.0  56.18333   10.23333
# 2      Abee    6            EH4  107000.0  1952.0  54.21667 -113.00000
# 3  Acapulco   10    Acapulcoite    1914.0  1976.0  16.88333  -99.90000
# 4   Achiras  370             L6     780.0  1902.0 -33.16667  -64.95000

# %%
# Drop rows with null or 0 value in column                         
csv_meteors_new = csv_meteors_new[csv_meteors_new.latitude != 0].dropna()
csv_meteors_new = csv_meteors_new[csv_meteors_new.longitude != 0].dropna()
csv_meteors_new = csv_meteors_new[csv_meteors_new.mass != 0].dropna()
csv_meteors_new = csv_meteors_new[csv_meteors_new.year != 0].dropna()

csv_meteors_new.count()
# Out:
# name              31688
# id                31688
# classification    31688
# mass              31688
# year              31688
# latitude          31688
# longitude         31688
# dtype: int64

# %%
# Delete all rows with mass of less than 100
csv_meteors_new2 = csv_meteors_new[csv_meteors_new['mass'] >=10000]
csv_meteors_new2.count()
# Out:
# name              1243
# id                1243
# classification    1243
# mass              1243
# year              1243
# latitude          1243
# longitude         1243
# dtype: int64

# %%
csv_meteors_new2.to_csv (r'C:/Users/ekatu/code/Project_2/Project-2-VisualizeMe2/Data/meteorite_landings_clean.csv', index = False, header = True)
# meteorite_landings_clean.csv
# C:\Users\ekatu\code\Project_2\Project-2-VisualizeMe2\Data

# %%
csv_meteors['year'] = csv_meteors.dropna()['year'].astype(np.int64)

# %%
# Plot a scatter graph to determine how the landings increased over years.

years = csv_meteors.year.unique()
landings = []

for year in years:
    landings.append(len(csv_meteors[csv_meteors.year == year]))

s = [x for x in landings]

plt.scatter(years, landings, s=s, c='r', edgecolors='black')
plt.xlabel('Year')
plt.xlim(xmin=800)
plt.xlim(xmax=2200)
plt.ylabel('Landings')
plt.ylim(ymin=0)
plt.ylim(ymax=3500)
# Out:
# (0.0, 3500.0)

# %%
# Let's take a look at the number of discoveries as a function of the latitude

plt.scatter(csv_meteors.year, csv_meteors.reclat,color='g',alpha=0.4)
plt.xlim(1800,2020)
plt.xlim(xmax=2020)
plt.ylim(-90,90)
plt.ylabel('Latitude')
plt.xlabel('Year')
plt.title('Meteorite recorded Latitude vs Year')
# Out:
# Text(0.5, 1.0, 'Meteorite recorded Latitude vs Year')
